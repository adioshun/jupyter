# %% [markdown]
# # Matplotlib
# [참고](http://www.labri.fr/perso/nrougier/teaching/matplotlib/)

# %% [markdown]
# ## 그래프 그리기

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
# Compute the x and y coordinates for points on a sine curve
x = np.arange(0, 3 * np.pi, 0.1)
y = np.sin(x)

# Plot the points using matplotlib
plt.plot(x, y)

# %%
y_sin = np.sin(x)
y_cos = np.cos(x)
# Plot the points using matplotlib
plt.plot(x, y_sin)
plt.plot(x, y_cos)
plt.xlabel('x axis label')
plt.ylabel('y axis label')
plt.title('Sine and Cosine')
plt.legend(['Sine', 'Cosine'])

# Show the figure.
plt.show()

# %%
# Compute the x and y coordinates for points 
# on sine and cosine curves
x = np.arange(0, 3 * np.pi, 0.1)
y_sin = np.sin(x)
y_cos = np.cos(x)

# Set up a subplot grid that has height 2 and width 1,
# and set the first such subplot as active.
plt.subplot(2, 1, 1)

# Make the first plot
plt.plot(x, y_sin)
plt.title('Sine')

# Set the second subplot as active, and make the second plot.
plt.subplot(2, 1, 2)
plt.plot(x, y_cos)
plt.title('Cosine')

# Show the figure.
plt.show()

# %% [markdown]
# ## 그림 출력하기

# %%
import matplotlib.pyplot as plt
from scipy.misc import imread, imresize
# %matplotlib inline  

cat = imread("/home/adioshun/datasets/cat.jpg")
plt.figure(0)
plt.imshow(cat)
plt.title("TEst Cat")
plt.draw()

# %% [markdown]
# 4 : plt.figure()는 새로운 figure를 생성해준다.
# 5 : plt.show()는 생성된 모든 figure를 보여준다.

# %% [markdown]
# ## 그림 변경하기

# %% [markdown]
# ### Resize

# %%
import matplotlib.pyplot as plt
from scipy.misc import imread, imresize
# %matplotlib inline  

cat = imread("/home/adioshun/datasets/cat.jpg")
catsmal = imresize(cat, [100,100,3])
plt.imshow(catsmal)
plt.draw
# Out:
# <function matplotlib.pyplot.draw>

# %% [markdown]
# ### Reshape

# %%
import matplotlib.pyplot as plt
from scipy.misc import imread, imresize
# %matplotlib inline  
cat.shape
#cat = imread("/home/adioshun/datasets/cat.jpg")
#catreshape = np.reshape(cat, (100,100,3))
# Out:
# (1200, 1600, 3)
